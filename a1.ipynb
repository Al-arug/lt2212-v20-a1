# %% [markdown]
# ## Assignment 1 testing ground
#
# You can change what you want here, but we won't be evaluating it.  We will run the original version of this notebook plus any additional secret tests we deem fit.

# %%
import a1
import matplotlib.pyplot as plt

# %%
df = a1.part1_load("grain", "crude",1000)

# %%
df
# Out:
#                files classes  "  '   ,  -   .  /  000  1  ...  pct   s  said  \
# 0     article581.txt   grain  0  0   2  0  10  0    0  0  ...    0   3     0
# 1     article580.txt   grain  0  0   4  2   0  0    2  0  ...    0   0     0
# 2     article579.txt   grain  2  0  11  3  10  0    0  0  ...    0   0     4
# 3     article578.txt   grain  0  1  10  0   9  0    3  0  ...    0   1     2
# 4     article577.txt   grain  0  0  20  1  26  2    0  0  ...    2   3     1
# ...              ...     ... .. ..  .. ..  .. ..  ... ..  ...  ...  ..   ...
# 1152  article004.txt   crude  1  3   9  4  17  0    0  1  ...    1   4     9
# 1153  article003.txt   crude  2  1   7  2   9  0    1  0  ...    0   1     8
# 1154  article002.txt   crude  2  1   6  1   9  0    0  0  ...    0   1     6
# 1155  article001.txt   crude  8  7  37  8  52  1    0  2  ...    7  16    10
# 1156  article000.txt   crude  0  1   8  2   6  3    0  0  ...    3   1     4
#
#       that  the  to  tonnes  u  was  will
# 0        0    9   5       0  3    0     0
# 1        0    0   0       2  0    0     0
# 2        2   39  12       0  0    1     2
# 3        0    0   4       4  0    0     0
# 4        2   30  20       0  3    3     1
# ...    ...  ...  ..     ... ..  ...   ...
# 1152     0   13   4       0  1    0     1
# 1153     1   10   2       0  0    1     0
# 1154     0   19   5       0  0    3     0
# 1155     8   43  16       0  9    1     3
# 1156     0   13   5       0  0    0     2
#
# [1157 rows x 35 columns]

# %%
plot = a1.part2_vis(df,10)

# %%
plot

# %%
df2 = a1.part3_tfidf(df)

# %%
plot2 = a1.part2_vis(df2,10)

# %% [markdown]
# You can do whatever else, including testing the bonus, here.
